# %% [markdown]
# **Calling necessary libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# calling all imp files and preview

# %%
dim_date = pd.read_csv("D:/Downloads/Input Files/Input Files/dim_date.csv")
dim_hotels = pd.read_csv("D:/Downloads/Input Files/Input Files/dim_hotels.csv")
dim_rooms = pd.read_csv("D:/Downloads/Input Files/Input Files/dim_rooms.csv")
fact_aggregated_bookings = pd.read_csv("D:/Downloads/Input Files/Input Files/fact_aggregated_bookings.csv")
fact_bookings = pd.read_csv("D:/Downloads/Input Files/Input Files/fact_bookings.csv")

# %%
dim_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
dim_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
dim_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
fact_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559     01-May-22           RT1                   25        30
# 1           19562     01-May-22           RT1                   28        30
# 2           19563     01-May-22           RT1                   23        30
# 3           17558     01-May-22           RT1                   13        19
# 4           16558     01-May-22           RT1                   18        19
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13        18
# 9196        16559     31-Jul-22           RT4                   13        18
# 9197        17558     31-Jul-22           RT4                    3         6
# 9198        19563     31-Jul-22           RT4                    3         6
# 9199        17561     31-Jul-22           RT4                    3         4
#
# [9200 rows x 5 columns]

# %%
fact_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1  May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2  May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
# 3  May012216558RT14        16558   2022-04-28    2022-05-01    2022-05-02
# 4  May012216558RT15        16558   2022-04-27    2022-05-01    2022-05-02
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0          3           RT1    direct online            1.0    Checked Out
# 1          2           RT1           others            NaN      Cancelled
# 2          2           RT1          logtrip            5.0    Checked Out
# 3          2           RT1           others            NaN      Cancelled
# 4          4           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %% [markdown]
# **making dic to mapping room category in fact_bookings**

# %%
dict(zip(dim_rooms.room_id, dim_rooms.room_class ))
# Out:
# {'RT1': 'Standard', 'RT2': 'Elite', 'RT3': 'Premium', 'RT4': 'Presidential'}

# %%
fact_bookings['room_class'] = fact_bookings['room_category'].map(dict(zip(dim_rooms.room_id, dim_rooms.room_class )))

# %%
fact_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1  May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2  May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
# 3  May012216558RT14        16558   2022-04-28    2022-05-01    2022-05-02
# 4  May012216558RT15        16558   2022-04-27    2022-05-01    2022-05-02
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0          3           RT1    direct online            1.0    Checked Out
# 1          2           RT1           others            NaN      Cancelled
# 2          2           RT1          logtrip            5.0    Checked Out
# 3          2           RT1           others            NaN      Cancelled
# 4          4           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized room_class
# ...

# %% [markdown]
# **merging table dim hotels by making dict on property id with fact_bookings**

# %%
a=dict(zip(dim_hotels['property_id'],dim_hotels['property_name']))
b=dict(zip(dim_hotels['property_id'],dim_hotels['category']))
c=dict(zip(dim_hotels['property_id'],dim_hotels['city']))

# %%
fact_bookings['property_name'] = fact_bookings['property_id'].map(a)
fact_bookings['category'] = fact_bookings['property_id'].map(b)
fact_bookings['city'] = fact_bookings['property_id'].map(c)

# %% [markdown]
# **merging table dim date by making dict on date column with fact_bookings**

# %%
e=dict(zip(dim_date['date'],dim_date['mmm yy']))
f=dict(zip(dim_date['date'],dim_date['week no']))
g=dict(zip(dim_date['date'],dim_date['day_type']))

# %%
fact_aggregated_bookings['mmm yy'] = fact_aggregated_bookings['check_in_date'].map(e)
fact_aggregated_bookings['week no'] = fact_aggregated_bookings['check_in_date'].map(f)
fact_aggregated_bookings['day_type'] = fact_aggregated_bookings['check_in_date'].map(g)

# %%
fact_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559     01-May-22           RT1                   25        30
# 1           19562     01-May-22           RT1                   28        30
# 2           19563     01-May-22           RT1                   23        30
# 3           17558     01-May-22           RT1                   13        19
# 4           16558     01-May-22           RT1                   18        19
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13        18
# 9196        16559     31-Jul-22           RT4                   13        18
# 9197        17558     31-Jul-22           RT4                    3         6
# 9198        19563     31-Jul-22           RT4                    3         6
# 9199        17561     31-Jul-22           RT4                    3         4
#
#       mmm yy week no day_type
# ...

# %% [markdown]
# # changing date format from 1/may/22 to 1/5/22

# %%
fact_aggregated_bookings['check_in_date']=pd.to_datetime(fact_aggregated_bookings['check_in_date'])

# %%
fact_aggregated_bookings.to_csv('fact_aggregated_bookings_new_df.csv')

# %% [markdown]
# ## making final table by joining and concating all tables

# %%
df = pd.concat([fact_bookings,fact_aggregated_bookings],join = 'outer', axis = 1)

# %%
df
# Out:
#                booking_id property_id booking_date check_in_date  \
# 0        May012216558RT11       16558   2022-04-27    2022-05-01
# 1        May012216558RT12       16558   2022-04-30    2022-05-01
# 2        May012216558RT13       16558   2022-04-28    2022-05-01
# 3        May012216558RT14       16558   2022-04-28    2022-05-01
# 4        May012216558RT15       16558   2022-04-27    2022-05-01
# ...                   ...         ...          ...           ...
# 134585   Jul312217564RT46       17564   2022-07-29    2022-07-31
# 134586   Jul312217564RT47       17564   2022-07-30    2022-07-31
# 134587   Jul312217564RT48       17564   2022-07-30    2022-07-31
# 134588   Jul312217564RT49       17564   2022-07-29    2022-07-31
# 134589  Jul312217564RT410       17564   2022-07-31    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0         2022-05-02          3           RT1    direct online            1.0
# ...

# %%
df.to_csv('final_df.csv')
